# %%
benimListe = [2,4,5,6,7]

# %%
benimListe
# Out:
# [2, 4, 5, 6, 7]

# %% [markdown]
# set içindeki elemanı sadece 1 defa barındırır en büyük özelliği bu

# %%
benimListe.append(5)

# %%
benimListe
# Out:
# [2, 4, 5, 6, 7, 5, 5]

# %%
benimSetListe = set(benimListe)

# %%
type(benimSetListe)
# Out:
# set

# %%
type(benimListe)
# Out:
# list
