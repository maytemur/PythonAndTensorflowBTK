# %%
import numpy as np
import matplotlib.pyplot as matplot
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
maasListesi = np.random.normal(4000,500,1000)
np.mean(maasListesi)
# Out:
# np.float64(4018.457629465947)

# %%
matplot.hist(maasListesi,50)
matplot.show()
