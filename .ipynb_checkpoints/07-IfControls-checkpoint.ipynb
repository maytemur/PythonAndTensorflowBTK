# %%
if 3>1 :
    print("maytemur")
# Out:
# maytemur

# %% [markdown]
# Pythonda boşluk baştan verilirse eski satır komutu devam ediyor demektir yeni satır sıfırdan başlar

# %%
if 3>5 :
    print("maytemur")
    print("burasıda çalışmaz")
print("if koşulunun dışına çıktık")
# Out:
# if koşulunun dışına çıktık

# %% [markdown]
# if elif ve else var tabiki elif else'in kısaltması aynı komut

# %%
benimString = "maytemur"

# %%
if "mayt" in benimString:
    print ("varmış")
else:
    print("yokmuş")
# Out:
# varmış

# %%
benimSozluk = {"muz":150,"elma":230,"karpuz":400}

# %%
if "muz" in benimSozluk.keys():
    print("varmış")
# Out:
# varmış

# %%
if 400 in benimSozluk.values():
    print("evet var")
# Out:
# evet var
