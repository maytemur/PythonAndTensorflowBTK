# %%
benimBoolean = True

# %%
benimBoolean
# Out:
# True

# %%
type(benimBoolean)
# Out:
# bool

# %%
10 < 3
# Out:
# False

# %%
listem = [20,45,36,57,86,79]

# %%
len(listem)
# Out:
# 6

# %%
sum(listem)
# Out:
# 323

# %%
kullaniciMaas = input("maasi girin")
# Out:
# maasi girin 25

# %%
type(kullaniciMaas)
# Out:
# str

# %%
kullaniciMaasInt = int(kullaniciMaas)

# %%
kullaniciMaasInt>1000
# Out:
# False

# %%
x= 8

# %%
y=6

# %%
x==y
# Out:
# False

# %%
x!=y
# Out:
# True
