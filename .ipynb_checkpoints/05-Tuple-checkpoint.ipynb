# %%
benimListe= [1,2,"a",4.5]

# %%
benimListe[0]
# Out:
# 1

# %%
benimTupleListe=(1,2,"b",3.4)

# %% [markdown]
# Bu parantez ile liste olunca Tuple yani değiştirilemez oluyor!

# %% [markdown]
# Tuple listede fazla yapılacak bir işlem yok count ve index var

# %%
benimTupleListe.count(2)
# Out:
# 1
