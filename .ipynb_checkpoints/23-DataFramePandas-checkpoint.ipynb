# %%
import pandas as pd
import numpy as np

# %%
data = np.random.rand(4,3)

# %%
data
# Out:
# array([[0.94875947, 0.14377651, 0.56856503],
#        [0.03524917, 0.49806596, 0.18180493],
#        [0.27079776, 0.18084472, 0.11797624],
#        [0.51405747, 0.35459012, 0.16067846]])

# %%
dataFrame = pd.DataFrame(data)

# %%
dataFrame
# Out:
#           0         1         2
# 0  0.948759  0.143777  0.568565
# 1  0.035249  0.498066  0.181805
# 2  0.270798  0.180845  0.117976
# 3  0.514057  0.354590  0.160678

# %%
yeniDataFrame = pd.DataFrame(data,index=["Atil","Zaynep","Atlas","Mehmet"],columns=["Maas","Yas","Calisma Saati"])

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Atil    0.948759  0.143777       0.568565
# Zaynep  0.035249  0.498066       0.181805
# Atlas   0.270798  0.180845       0.117976
# Mehmet  0.514057  0.354590       0.160678

# %%
yeniDataFrame["Yas"]
# Out:
# Atil      0.143777
# Zaynep    0.498066
# Atlas     0.180845
# Mehmet    0.354590
# Name: Yas, dtype: float64

# %%
yeniDataFrame["Maas"]
# Out:
# Atil      0.948759
# Zaynep    0.035249
# Atlas     0.270798
# Mehmet    0.514057
# Name: Maas, dtype: float64

# %%
yeniDataFrame[["Maas","Yas"]]
# Out:
#             Maas       Yas
# Atil    0.948759  0.143777
# Zaynep  0.035249  0.498066
# Atlas   0.270798  0.180845
# Mehmet  0.514057  0.354590

# %%
yeniDataFrame.loc["Atil"] #locate kısaltması dedi
# Out:
# Maas             0.948759
# Yas              0.143777
# Calisma Saati    0.568565
# Name: Atil, dtype: float64

# %%
yeniDataFrame.iloc[1]
# Out:
# Maas             0.035249
# Yas              0.498066
# Calisma Saati    0.181805
# Name: Zaynep, dtype: float64

# %%
yeniDataFrame["Emeklilik Yasi"] = yeniDataFrame["Yas"] + yeniDataFrame["Yas"]

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Atil    0.948759  0.143777       0.568565        0.287553
# Zaynep  0.035249  0.498066       0.181805        0.996132
# Atlas   0.270798  0.180845       0.117976        0.361689
# Mehmet  0.514057  0.354590       0.160678        0.709180

# %%
yeniDataFrame.drop("Maas",axis=1)
# Out:
#              Yas  Calisma Saati  Emeklilik Yasi
# Atil    0.143777       0.568565        0.287553
# Zaynep  0.498066       0.181805        0.996132
# Atlas   0.180845       0.117976        0.361689
# Mehmet  0.354590       0.160678        0.709180

# %%
yeniDataFrame.drop("Mehmet",axis=0)
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Atil    0.948759  0.143777       0.568565        0.287553
# Zaynep  0.035249  0.498066       0.181805        0.996132
# Atlas   0.270798  0.180845       0.117976        0.361689

# %%
yeniDataFrame # inplace option yazılmazsa gerçek değişiklik yapmıyor
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Atil    0.948759  0.143777       0.568565        0.287553
# Zaynep  0.035249  0.498066       0.181805        0.996132
# Atlas   0.270798  0.180845       0.117976        0.361689
# Mehmet  0.514057  0.354590       0.160678        0.709180

# %%
yeniDataFrame.drop("Mehmet",axis=0,inplace=True)

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Atil    0.948759  0.143777       0.568565        0.287553
# Zaynep  0.035249  0.498066       0.181805        0.996132
# Atlas   0.270798  0.180845       0.117976        0.361689

# %%
yeniDataFrame.loc["Atil"]["Yas"]
# Out:
# np.float64(0.14377651032871475)

# %%
yeniDataFrame.loc["Atil","Yas"]
# Out:
# np.float64(0.14377651032871475)

# %%
yeniDataFrame < 0
# Out:
#          Maas    Yas  Calisma Saati  Emeklilik Yasi
# Atil    False  False          False           False
# Zaynep  False  False          False           False
# Atlas   False  False          False           False

# %%
booleanFrame = yeniDataFrame < 0

# %%
yeniDataFrame[booleanFrame]
# Out:
#         Maas  Yas  Calisma Saati  Emeklilik Yasi
# Atil     NaN  NaN            NaN             NaN
# Zaynep   NaN  NaN            NaN             NaN
# Atlas    NaN  NaN            NaN             NaN

# %%
yeniDataFrame[yeniDataFrame["Yas"] > 0] # Yas kolonunda bana sadece 0 dan büyük olanları getir dedik
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Atil    0.948759  0.143777       0.568565        0.287553
# Zaynep  0.035249  0.498066       0.181805        0.996132
# Atlas   0.270798  0.180845       0.117976        0.361689

# %%
yeniDataFrame.reset_index()
# Out:
#     index      Maas       Yas  Calisma Saati  Emeklilik Yasi
# 0    Atil  0.948759  0.143777       0.568565        0.287553
# 1  Zaynep  0.035249  0.498066       0.181805        0.996132
# 2   Atlas  0.270798  0.180845       0.117976        0.361689

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Atil    0.948759  0.143777       0.568565        0.287553
# Zaynep  0.035249  0.498066       0.181805        0.996132
# Atlas   0.270798  0.180845       0.117976        0.361689

# %%
yeniIndexListesi= ["Ati","Zey","Atl"]

# %%
yeniDataFrame["Yeni Indeks"] = yeniIndexListesi

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi Yeni Indeks
# Atil    0.948759  0.143777       0.568565        0.287553         Ati
# Zaynep  0.035249  0.498066       0.181805        0.996132         Zey
# Atlas   0.270798  0.180845       0.117976        0.361689         Atl

# %%
yeniDataFrame.set_index("Yeni Indeks")
# Out:
#                  Maas       Yas  Calisma Saati  Emeklilik Yasi
# Yeni Indeks
# Ati          0.948759  0.143777       0.568565        0.287553
# Zey          0.035249  0.498066       0.181805        0.996132
# Atl          0.270798  0.180845       0.117976        0.361689

# %%
yeniDataFrame.set_index("Yeni Indeks",inplace = True)

# %%
yeniDataFrame
# Out:
#                  Maas       Yas  Calisma Saati  Emeklilik Yasi
# Yeni Indeks
# Ati          0.948759  0.143777       0.568565        0.287553
# Zey          0.035249  0.498066       0.181805        0.996132
# Atl          0.270798  0.180845       0.117976        0.361689

# %%
yeniDataFrame.loc["Ati"]
# Out:
# Maas              0.948759
# Yas               0.143777
# Calisma Saati     0.568565
# Emeklilik Yasi    0.287553
# Name: Ati, dtype: float64

# %% [markdown]
# ## MultiIndeks

# %%
ilkIndexler = ["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
icIndeksler = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
birlesmisIndeks = list(zip(ilkIndexler,icIndeksler))

# %%
birlesmisIndeks
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
birlesmisIndeks = pd.MultiIndex.from_tuples(birlesmisIndeks)

# %%
birlesmisIndeks
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
type(birlesmisIndeks)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
benimCizgiFilmListem = [[40,"A"],[10,"B"],[30,"C"],[9,"D"],[10,"E"],[11,"F"]]

# %%
cizgiFilmNumpyDizisi = np.array(benimCizgiFilmListem)

# %%
cizgiFilmDataFrame = pd.DataFrame(cizgiFilmNumpyDizisi,index=birlesmisIndeks,columns=["Yas","Meslek"])

# %%
cizgiFilmDataFrame
# Out:
#                    Yas Meslek
# Simpson    Homer    40      A
#            Bart     10      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    10      E
#            Kyle     11      F

# %%
cizgiFilmDataFrame.loc["Simpson"]
# Out:
#       Yas Meslek
# Homer  40      A
# Bart   10      B
# Marge  30      C

# %%
cizgiFilmDataFrame.loc["South Park"].loc["Kenny"]
# Out:
# Yas       10
# Meslek     E
# Name: Kenny, dtype: object

# %%
cizgiFilmDataFrame.index.names = ["Film Adı","İsim"]

# %%
cizgiFilmDataFrame
# Out:
#                    Yas Meslek
# Film Adı   İsim
# Simpson    Homer    40      A
#            Bart     10      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    10      E
#            Kyle     11      F
