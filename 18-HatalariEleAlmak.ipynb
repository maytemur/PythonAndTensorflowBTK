# %%
def toplama (no1,no2):
    return no1+no2

# %%
x = input ("ilk no yu girin: ")
y = input ("ilk no yu girin: ")
toplama (x,y)
# Out:
# ilk no yu girin:  23
# ilk no yu girin:  34
# '2334'

# %% [markdown]
# ## try - except - else - finally

# %%
while True:
    try:
        benimInt = int (input("Noyu giriniz: "))
    except:
        print("Lütfen gerçek bir no giriniz")
        continue
    else:
        print("Teşekkürler")
        break
    finally:
        print("finally çağrıldı")
# Out:
# Noyu giriniz:  er
# Lütfen gerçek bir no giriniz
# finally çağrıldı
# Noyu giriniz:  4
# Teşekkürler
# finally çağrıldı
