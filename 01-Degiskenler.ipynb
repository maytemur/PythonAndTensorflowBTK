# %%
5*4
# Out:
# 20

# %%
100+256
# Out:
# 356

# %% [raw]
# Python Öğreniyoruz BTK TensorFlow

# %%
x=6
y=4

# %%
x/y
# Out:
# 1.5

# %%
## Buda inline not alma normal ide de comment gibi

# %% [markdown]
# Klasik Atıl dersi bakalım yine yemek kitabı yapılacak mı ?
