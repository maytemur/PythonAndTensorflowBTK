# %% [markdown]
# Key-value pairing (anahtar kelime -değer eşleşmesi)

# %%
benimSozluk = {"anahtar" : "deger"}

# %%
type(benimSozluk)
# Out:
# dict

# %%
benimSozluk["anahtar"]
# Out:
# 'deger'

# %%
benimKaloriSozlugu = {"elma":150,"karpuz": 154,"muz":562}

# %%
benimKaloriSozlugu ["elma"]
# Out:
# 150

# %%
benimKaloriSozlugu ["elma"] =356

# %%
benimKaloriSozlugu ["elma"]
# Out:
# 356
