# %%
import pandas as pd
import numpy as np

# %%
sozluk1 = {"Isim" : ["Ahmet","Mehmet","Zeynep","Atıl"],
          "Spor" : ["Koşu","Yüzme","Koşu","Basketbol"],
          "Kalori" : [123,145,235,567]}

# %%
dataFrame1 = pd.DataFrame(sozluk1,index = [0,1,2,3])

# %%
dataFrame1
# Out:
#      Isim       Spor  Kalori
# 0   Ahmet       Koşu     123
# 1  Mehmet      Yüzme     145
# 2  Zeynep       Koşu     235
# 3    Atıl  Basketbol     567

# %%
sozluk2 = {"Isim" : ["Osman","Levent","Atlas","Fatma"],
          "Spor" : ["Koşu","Yüzme","Koşu","Basketbol"],
          "Kalori" : [223,345,535,667]}

# %%
dataFrame2 = pd.DataFrame(sozluk2,index = [4,5,6,7])

# %%
sozluk3 = {"Isim" : ["Ayşe","Mahmut","Duygu","Nur"],
          "Spor" : ["Koşu","Yüzme","Tenis","Voleybol"],
          "Kalori" : [223,345,535,667]}

# %%
dataFrame3 = pd.DataFrame(sozluk3,index = [8,9,10,11])

# %%
dataFrame2
# Out:
#      Isim       Spor  Kalori
# 4   Osman       Koşu     223
# 5  Levent      Yüzme     345
# 6   Atlas       Koşu     535
# 7   Fatma  Basketbol     667

# %%
dataFrame3
# Out:
#       Isim      Spor  Kalori
# 8     Ayşe      Koşu     223
# 9   Mahmut     Yüzme     345
# 10   Duygu     Tenis     535
# 11     Nur  Voleybol     667

# %% [markdown]
# ## concatenation

# %%
pd.concat([dataFrame1,dataFrame2,dataFrame3],axis = 0)
# Out:
#       Isim       Spor  Kalori
# 0    Ahmet       Koşu     123
# 1   Mehmet      Yüzme     145
# 2   Zeynep       Koşu     235
# 3     Atıl  Basketbol     567
# 4    Osman       Koşu     223
# 5   Levent      Yüzme     345
# 6    Atlas       Koşu     535
# 7    Fatma  Basketbol     667
# 8     Ayşe       Koşu     223
# 9   Mahmut      Yüzme     345
# 10   Duygu      Tenis     535
# 11     Nur   Voleybol     667

# %% [markdown]
# ## merge

# %%
mergeSozluk1 = {"Isim" : ["Ahmet","Mehmet","Zeynep","Atıl"],
               "Spor" : ["Koşu","Yüzme","Koşu","Basketbol"]}

# %%
mergeDataFrame1 = pd.DataFrame(mergeSozluk1)

# %%
mergeDataFrame1
# Out:
#      Isim       Spor
# 0   Ahmet       Koşu
# 1  Mehmet      Yüzme
# 2  Zeynep       Koşu
# 3    Atıl  Basketbol

# %%
mergeSozluk2 = {"Isim" : ["Ahmet","Mehmet","Zeynep","Atıl"],
               "Kalori" : [234,235,467,767]}

# %%
mergeDataFrame2 = pd.DataFrame(mergeSozluk2)

# %%
mergeDataFrame2
# Out:
#      Isim  Kalori
# 0   Ahmet     234
# 1  Mehmet     235
# 2  Zeynep     467
# 3    Atıl     767

# %%
pd.merge(mergeDataFrame1,mergeDataFrame2,on="Isim")
# Out:
#      Isim       Spor  Kalori
# 0   Ahmet       Koşu     234
# 1  Mehmet      Yüzme     235
# 2  Zeynep       Koşu     467
# 3    Atıl  Basketbol     767

# %%
maasSozluk = {"Isim" : ["Atıl","Zeynep","Mehmet","Ahmet"],
             "Departman" : ["Yazılım","Satış","Pazarlama","Yazılım"],
             "Maas" : [234,345,346,757]}

# %%
maasDataFrame = pd.DataFrame(maasSozluk)

# %%
maasDataFrame
# Out:
#      Isim  Departman  Maas
# 0    Atıl    Yazılım   234
# 1  Zeynep      Satış   345
# 2  Mehmet  Pazarlama   346
# 3   Ahmet    Yazılım   757

# %%
maasDataFrame["Departman"].unique()
# Out:
# array(['Yazılım', 'Satış', 'Pazarlama'], dtype=object)

# %%
maasDataFrame["Departman"].nunique()
# Out:
# 3

# %%
maasDataFrame["Departman"].value_counts()
# Out:
# Departman
# Yazılım      2
# Satış        1
# Pazarlama    1
# Name: count, dtype: int64

# %%
def bruttenNete(maas) :
    return maas * 0.66

# %%
maasDataFrame["Maas"].apply(bruttenNete)
# Out:
# 0    154.44
# 1    227.70
# 2    228.36
# 3    499.62
# Name: Maas, dtype: float64

# %%
maasDataFrame.isnull()
# Out:
#     Isim  Departman   Maas
# 0  False      False  False
# 1  False      False  False
# 2  False      False  False
# 3  False      False  False

# %%
yeniBirVeri = {"Karakter Sınıf" : ["South Park", "South Park", "Simpson", "Simpson","Simpson"],
              "Karakter Ismi" : ["Cartman", "Kenny", "Homer", "Bart","Bart"],
              "Karakter Yas" : [6,12,45,57,23]}

# %%
karakterDF = pd.DataFrame(yeniBirVeri)

# %%
karakterDF
# Out:
#   Karakter Sınıf Karakter Ismi  Karakter Yas
# 0     South Park       Cartman             6
# 1     South Park         Kenny            12
# 2        Simpson         Homer            45
# 3        Simpson          Bart            57
# 4        Simpson          Bart            23

# %%
karakterDF.pivot_table(values = "Karakter Yas", index = ["Karakter Sınıf", "Karakter Ismi"])
# Out:
#                               Karakter Yas
# Karakter Sınıf Karakter Ismi
# Simpson        Bart                   40.0
#                Homer                  45.0
# South Park     Cartman                 6.0
#                Kenny                  12.0

# %%
karakterDF.pivot_table(values = "Karakter Yas", index = ["Karakter Sınıf", "Karakter Ismi"],aggfunc=np.sum)
# Out:
# C:\Users\maytemur\AppData\Local\Temp\ipykernel_12508\954744810.py:1: FutureWarning: The provided callable <function sum at 0x0000027869B54040> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   karakterDF.pivot_table(values = "Karakter Yas", index = ["Karakter Sınıf", "Karakter Ismi"],aggfunc=np.sum)
#                               Karakter Yas
# Karakter Sınıf Karakter Ismi
# Simpson        Bart                     80
#                Homer                    45
# South Park     Cartman                   6
#                Kenny                    12
