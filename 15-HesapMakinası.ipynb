# %%
def hesapla(a,b,islem):
    if islem not in "+-*/":
        return "Lütfen şu işlemlerden birini seçiniz: +-*/"
        
    if islem == "+":
        return (str(a)+" + "+str(b) +" = " + str(a+b))
    if islem == "-":
        return (str(a)+" - "+str(b) +" = " + str(a-b))
    if islem == "*":
        return (str(a)+" * "+str(b) +" = " + str(a*b))
    if islem == "/":
        return (str(a)+" / "+str(b) +" = " + str(a/b))
while True:
    try:
        a= int(input("ilk sayıyı giriniz: "))
        b=int(input("ikinci sayıyı giriniz: "))
        islem = input("işleminiz seçiniz: +-*/")
        print(hesapla(a,b,islem))
    except:
        print("Lütfen sayıları düzgün girniz")
# Out:
# ilk sayıyı giriniz:  23
# ikinci sayıyı giriniz:  45
# işleminiz seçiniz: +-*/ GF
# Lütfen şu işlemlerden birini seçiniz: +-*/
# ilk sayıyı giriniz:  3
# ikinci sayıyı giriniz:  2
# işleminiz seçiniz: +-*/ ER
# Lütfen şu işlemlerden birini seçiniz: +-*/
# ilk sayıyı giriniz:  4
# ikinci sayıyı giriniz:  5
# işleminiz seçiniz: +-*/ /
# 4 / 5 = 0.8
# Lütfen sayıları düzgün girniz
