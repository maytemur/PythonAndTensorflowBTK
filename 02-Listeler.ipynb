# %% [markdown]
# Koleksiyonlar birden fazla değişken tipini bir listede tutmamıza yarar

# %%
benimString= "Mustafa Aytemür"

# %%
benimString[3]
# Out:
# 't'

# %% [markdown]
# Bunlarda en büyük farklılık mutable ve immmutability yani değişebilirlik veya değişemezlik

# %%
benimListem = [10,20,30,40]

# %%
type(benimListem)
# Out:
# list

# %%
benimNo = 5

# %%
benimDigerNo = 45

# %%
benimNoListem = [benimNo,benimDigerNo]

# %%
benimNoListem [0] = 34

# %%
benimNoListem
# Out:
# [34, 45]

# %%
benimListem.append(32)

# %%
benimListem
# Out:
# [10, 20, 30, 40, 32]

# %%
karisikListe = [1,2,3.5,"mustafa",78]

# %%
type(karisikListe)
# Out:
# list

# %%
sonucum = karisikListe[1]

# %%
type(sonucum)
# Out:
# int

# %%
listeListeicinde = [1,5,"mustafa",45,[34,"ayt"]]

# %%
type(listeListeicinde[4])
# Out:
# list

# %%
icdekiListeelemani = listeListeicinde[4][1]

# %%
icdekiListeelemani
# Out:
# 'ayt'
